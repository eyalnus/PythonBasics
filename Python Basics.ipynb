# %% [markdown]
# # Interpreted Language

# %% [markdown]
# Immediate mode allows running code one the fly. Variables remain for entire session.

# %%
2+2
# Out:
# 4

# %%
a=2+2

# %%
a
# Out:
# 4

# %%
b=a**2
b
# Out:
# 16

# %%
b++
# Out:
#   File "<ipython-input-17-bf80fa6f64a4>", line 1
#     b++
#        ^
# SyntaxError: invalid syntax

# %%
b+=1
print(b)
# Out:
# 17

# %% [markdown]
# # Variables

# %% [markdown]
# Python variabes are dynamically typed, which means they are checked at runtime.<br>
# Additionally, the variable type can change throughout the lifetime of the program.<br>
# Variable names must start with an underscode or letter; can contain underscores, letters and numbers; are case sensitive.

# %%
myVar = 33
print(myVar)
print(type(myVar))
myVar = 1.1
print(myVar)
print(type(myVar))
# Out:
# 33
# <class 'int'>
# 1.1
# <class 'float'>

# %%
(42).bit_length()
# Out:
# 6

# %%
fminutes = 415.
print(type(fminutes))
nminutes = 415
print(type(nminutes))
# Out:
# <class 'float'>
# <class 'int'>

# %%
fhours=fminutes/60
nhours=nminutes/60
print(fhours, type(fhours))
print(nhours, type(nhours))
# Out:
# 6.916666666666667 <class 'float'>
# 6.916666666666667 <class 'float'>

# %%
fhours=fminutes//60
nhours=nminutes//60
print(fhours, type(fhours))
print(nhours, type(nhours))
# Out:
# 6.0 <class 'float'>
# 6 <class 'int'>

# %%
print(fminutes % 60)
print(nminutes % 60)
# Out:
# 55.0
# 55

# %%
int(fhours)
# Out:
# 6

# %%
float(nhours)
# Out:
# 6.0

# %%
fhours == nhours
# Out:
# True

# %%
type(fminutes) == type(nminutes)
# Out:
# False

# %%
print(0,bool(0))
print(1, bool(1))
print(-1, bool(-1))
print(0e11, bool(0e11))
print("", bool(""))
print(" ", bool(" "))
print("False", bool("False"))
# Out:
# 0 False
# 1 True
# -1 True
# 0.0 False
#  False
#   True
# False True

# %% [markdown]
# # Strings

# %% [markdown]
# Python does not use "character" varaible types, only strings. Strings are declared between single or double quotes. The following are all valid:<br>
# 'Hello World'<br>
# "Hello World"<br>
# """Hello <br>
# World"""<br>
# '''Hello<br>
# World'''<br>
# <br>
# Single quotes can be placed inside double quoted strings, and double quotes inside single quoted strings.<br>
# "This 'String' is valid"<br>
# 'This "String" is also valid'<br>
# <br>
# Triple quotes take raw text input and transform it into a string literal.

# %%
s1="""Inside this string,
we will find 'single' quotes.\nWhich means the string will be surrounded with
double quotes."""
print(s1)
s1
# Out:
# Inside this string,
# we will find single quotes.
# Which means the string will be surrounded with
# double 'quotes'
# "Inside this string,\nwe will find single quotes.\nWhich means the string will be surrounded with\ndouble 'quotes'"

# %%
s2="""However, using "double" quotes will cause the string to be surrounded by single quotes."""
print(s2)
s2
# Out:
# However,
# using "double" quotes will cause the string to be surrounded by single quotes.
# 'However,\nusing "double" quotes will cause the string to be surrounded by single quotes.'

# %%
q="""What will using both 'single' and "double" quotes cause?"""
print(q)
q
# Out:
# What will using both 'single' and "double" quotes cause?
# 'What will using both \'single\' and "double" quotes cause?'

# %% [markdown]
# **String objects are also Sequence Types, and support a variety of sequence related functions.**

# %%
data="Scientific Programming with Python!"

# %%
print(""""data" length: """, len(data))
print("P in data:", "P" in data)
print("S not in data:", 'S' not in data)
print("Index of P in data: ", data.index('P'))
# Out:
# "data" length:  35
# P in data: True
# S not in data: False
# Index of P in data:  11

# %% [markdown]
# **String objects are immutable, meaning once created they cannot be modified. Any modification actually creates a new string.**

# %%
str1 = "It was the best of times."
str2 = str1.replace('best','worst')
print(str1, str2)
# Out:
# It was the best of times. It was the worst of times.

# %% [markdown]
# **Indexing**

# %%
print("data[17]:", data[17])
print("data[-1]:", data[-1])
print("data[17:-3]:", data[17:-3])
print("data[0:-1:4]:", data[0:-1:4])
# Out:
# data[17]: m
# data[-1]: !
# data[17:-3]: mming with Pyth
# data[0:-1:4]: SniraniPo

# %% [markdown]
# **Concatenation**

# %%
moreData = data + "!!"
print(moreData)
evenMoreData = data*5
print(evenMoreData)
# Out:
# Scientific Programming with Python!!!
# Scientific Programming with Python!Scientific Programming with Python!Scientific Programming with Python!Scientific Programming with Python!Scientific Programming with Python!

# %%
fl = 44.12
numberString = "55" + str(fl)
print(numberString)
# Out:
# 5544.12

# %% [markdown]
# **String Formatting**<br>
# Strings use '{}' as placeholders which can be filled with variables and formatted.

# %%
"{} and {} and {}, Oh my!".format('lions', 'tigers', 'bears')
# Out:
# 'lions and tigers and bears, Oh my!'

# %%
"{1} and {2} and {0}, Oh my!".format('lions', 'tigers', 'bears')
# Out:
# 'tigers and bears and lions, Oh my!'

# %%
"{1} and {1} and {1}, Oh my!".format('lions', 'tigers', 'bears')
# Out:
# 'tigers and tigers and tigers, Oh my!'

# %%
import string
"{0[7]}{1[4]}{1[11]}{1[11]}{1[14]} {0[22]}{1[14]}{1[17]}{1[11]}{1[3]}.".format(string.ascii_uppercase, string.ascii_lowercase)
# Out:
# 'Hello World.'

# %%
print("It's always {weather} in {city}.".format(weather="sunny", city="philadelphia"))
# Out:
# It's always sunny in philadelphia

# %%
print("int: {0:d};  hex: {0:x};  oct: {0:o};  bin: {0:b}".format(1337))
print("int: {0:d};  hex: {0:#x};  oct: {0:#o};  bin: {0:#b}".format(1337))
print("exp: {0:e}, rounded: {0:.3f}".format(12345.6789))
# Out:
# int: 1337;  hex: 539;  oct: 2471;  bin: 10100111001
# int: 1337;  hex: 0x539;  oct: 0o2471;  bin: 0b10100111001
# exp: 1.234568e+04, rounded: 12345.679

# %%
dataList = data.split(' ')
print(dataList)
# Out:
# ['Scientific', 'Programming', 'with', 'Python!']

# %%
"{0[1]} {0[2]} {0[0]} {0[3]}".format(dataList)
# Out:
# 'Programming with Scientific Python!'

# %% [markdown]
# # Flow Control

# %% [markdown]
# Conditional statements in Python:<br>
# if \< condition_1 \>:<br>
# &emsp;\< action_1 \><br>
# elif \< condition_2 \>:<br>
# &emsp;\< action_2 \>:<br>
# ...<br>
# elif \< condition_k \>:<br>
# &emsp;\< action_k \>:<br>
# else:<br>
# &emsp;\< fallback_action \>

# %%
from random import random
num = random()
print(num)
if num > 0.5:
    if num < 0.75:
        print("good")
    else:
        print("great")
elif num > 0.25:
    print("poor")
else:
    print("awful")
# Out:
# 0.5868039669736207
# good

# %% [markdown]
# **Conditional loops using "while"**<br>
# while \< condition \>:<br>
# &emsp;\< loop_action \><br>
# else:<br>
# &emsp;\< condition_false_action \><br>
# <br>
# *Note: the else clause is optional and won't be performed if the loop ended due to a **break** call.*

# %%
i = 10
prod = 1
while(i > 0):
    prod *= i
    i-=1
else:
    print(i)
print("{:,}".format(prod))
# Out:
# 0
# 3,628,800

# %% [markdown]
# # Functions

# %% [markdown]
# A function is a block of organized, reusable code. Functions provide better modularity for your application and a high degree of code reusing. In addition, they also make your code more readable, as they keep the main code simple by assigning tasks to auxiliary funtions.
#
# We've seen some of Python's built-in functions like _int()_, _print()_, _type()_, etc., and object functions such as those belonging to **string**s. We will now learn how to create user-defined functions.
#
# A function receives input arguments and **returns** some output based on them. Both the input and the output can in general contain zero arguments, for example the function _print()_ returns no argument and the _bit\_length()_ function if **int** receives no input.
#
# Every function definition starts with a _signature_, containing the prefix **def** followed by the name of the function and parentheses, in which the input arguments are listed. Then, following a colon and an indentation, the function block is written, possibly containing a **return** statement(s). As python is dynamically typed, there is not declaration of return type for functions.

# %%
def add(a,b):
    total = a + b
    return total
print (add(12,-9))
# Out:
# 3

# %%
def strToBool(s):
    test = s.lower()
    if test == "false" or test == "f":
        return False
    elif s.lower() == "true" or test == "t":
        return True
    return None
print(strToBool("FAlsE"))
print(strToBool("true"))
print(strToBool("t"))
print(strToBool("F"))

print(strToBool("Maybe"))
# Out:
# False
# True
# True
# False
# None

# %% [markdown]
# **None** is the Python equivalent of **null**. The comparison is not one to one, as Python's **None** is an object in its own right, however the use is similar.

# %%
print(type(None))
print(bool(None))
print(strToBool("fa") is None)
# Out:
# <class 'NoneType'>
# False
# True

# %% [markdown]
# In Python, a function can return multiple values for a single function call. When calling such a function, we can accept all returned values into one variable, which will hold a Python **tuple** object. A **tuple** is an immutable ordered collection in Python. Alternatively, we can **unpack** the returned values accross multiple variables, each holding one value. For the latter option, we must know how many values are returned.

# %%
def calculate(a,b):
    c1= a+b 
    c2= a-b 
    c3= a*b
    c4= 0 if b == 0 else a/b
    return c1, c2, c3, c4
tup = calculate(80,15)
v1,v2,v3,v4 = calculate(10,0)
#p1,p2 = calculate(11,12) #error
print("tuple: ", tup)
print("values: ",v1,v2,v3,v4)
# Out:
# tuple:  (95, 65, 1200, 5.333333333333333)
# values:  10 10 0 0

# %% [markdown]
# **Functions can define default values for input parameters. All non-default params must come before default params.**

# %%
def prints(s,caps=False):
    s_ = str(s)
    toPrint = s_.upper() if caps else s_
    print(toPrint)

prints("This sentence is printed as is.")
prints("this one is all caps",True)
prints(True,True)
prints(False,True)
# Out:
# This sentence is printed as is.
# THIS ONE IS ALL CAPS
# TRUE
# FALSE

# %% [markdown]
# **Function input parameters are assigned in the order they are sent, however they can be explicitely defined in the function call**

# %%
implicit=calculate(2,4)
explicit=calculate(b=2,a=4)
print("implicit:",implicit)
print("explicit:",explicit)
# Out:
# implicit: (6, -2, 8, 0.5)
# explicit: (6, 2, 8, 2.0)

# %%
def poly(a,b=1,c=1,d=0):
    return str(a)+"x^3 + " + str(b) + "x^2 + " + str(c) + "x + " + str(d)  

print("1:",poly(2))
print("2:",poly(2,3))
print("3:",poly(2,3,4))
print("4:",poly(2, d=9))
print("5:",poly(10,11,d=17))
##print("6:",poly()) #error - at least 1 param required
##print("7:",poly(2, b=8, 15)) #error - can't have positional argument after keyword
##print("8:",poly(2, 7, b=12)) #error - b received multiple values: positional + keyword
# Out:
# 1: 2x^3 + 1x^2 + 1x + 0
# 2: 2x^3 + 3x^2 + 1x + 0
# 3: 2x^3 + 3x^2 + 4x + 0
# 4: 2x^3 + 1x^2 + 1x + 9
# 5: 10x^3 + 11x^2 + 1x + 17

# %% [markdown]
# What if we want to expand the above _polynomial_ function so that we can have more coeffiecents and degrees? Python uses the <font color="red">**\*args**</font> input parameter for variable length input. The input will be stored in a **tuple** object. We can *iterate* over this **tuple** using the <font color="blue">**for**</font> statement. In Python, the <font color="blue">**for**</font> statement is declared as follows:<br>
# for \< iterator \> in \< iterable \>:<br>
# &emsp;\< perform_action \><br>
# else:<br>
# &emsp;\< perform_end_iteration_action \><br>
# <br>
# *Note: the else clause is optional and won't be performed if the loop ended due to a **break** call.*

# %%
def polynom(*coefficients):
    res=""
    p = len(coefficients) - 1 
    for c in coefficients:
        if type(c) in (int, float): #check if the type of c is s number
            if c != 0:
                if p!= 0 and p!=1:
                    term = "{}x^{}".format(c,p)
                elif p == 1:
                    term = str(c)+"x"
                else:
                    term = str(c)
                if res == "":
                    res = term
                else:
                    res += " + "+term
        p-=1
    return res

# %%
polynom(5,4,3,2,1)
# Out:
# '5x^4 + 4x^3 + 3x^2 + 2x + 1'

# %%
polynom(5.5,4.4,3.3,2e-4,1)
# Out:
# '5.5x^4 + 4.4x^3 + 3.3x^2 + 0.0002x + 1'

# %%
polynom(0,13,0,37,0)
# Out:
# '13x^3 + 37x'

# %%
polynom(17, "a", 100, 90, 80, (13,14,15), 0, 0, 7 )
# Out:
# '17x^8 + 100x^6 + 90x^5 + 80x^4 + 7'
